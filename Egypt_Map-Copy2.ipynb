# %%
import os
import numpy as np
import pandas as pd
import folium
#pd.options.display.width = 0
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
import folium
import pandas as pd
import json
from folium import plugins

# %%
c = "Test.csv"    
c = pd.read_csv(c,dtype={'city': object})

# %%
c[:2]
# Out:
#     city  population       lat        lng
# 0  Cairo    11893000  30.07708  31.285909
# 1  Cairo    11893000  30.07708  31.285909

# %%
#numSeries = c.groupby(['city']).count().population
#numDistrict = pd.DataFrame()
#numDistrict['city'] = [str(i) for i in numSeries.index]
#numDistrict['count'] = numSeries.values
#numDistrict.sort_values(by='count',ascending=False).head()

# %%
#numDistrict
#numSeries.values
geopath = 'eg.geojson'

District_Map = folium.Map(location=[30.173217, 31.88695], zoom_start=9)

# %%
#choropleth = District_Map.choropleth(geo_data = geopath)   # A label under the bar

# %%
folium.TileLayer('stamenTerrain').add_to(District_Map)

# %%
District_Map.save('District_Map_Crimes.html')

# %%
hospitals = pd.read_csv('hospitals.csv')

# %%
hospitals[['lat','lng']][:2]
# Out:
#          lat        lng
# 0  30.035425  30.799747
# 1  30.187485  30.929959

# %%
import random
import decimal

coordinates = []
for i in range(50):
    lst = []
    
    Lat_val= random.randrange(29951505,31028770)/1000000
    lst.append(Lat_val)
    
    lng_val= random.randrange(30708612,31315644)/1000000
    
    lst.append(lng_val)
    
    coordinates.append(lst)

# %%
coordinates[:5]
# Out:
# [[30.458944, 30.919836],
#  [31.016464, 30.833667],
#  [30.185316, 30.955762],
#  [30.632362, 30.884015],
#  [30.4596, 30.985978]]

# %%
cases = pd.DataFrame(coordinates,columns = ['lat','lng'])

# %%
cases[:2]
# Out:
#          lat        lng
# 0  30.458944  30.919836
# 1  31.016464  30.833667

# %%
#cases.to_csv('hospitals.csv')

# %%
for i in range(0,len(cases)):
    folium.Marker([cases.iloc[i]['lat'], cases.iloc[i]['lng']], icon=folium.Icon(color='white', icon='fa-male',icon_color="black", prefix='fa')).add_to(District_Map)

# %%
for i in range(len(hospitals)):
    folium.Marker([hospitals.iloc[i]['lat'], hospitals.iloc[i]['lng']], icon=folium.Icon(color='white', icon='fa-ambulance',icon_color="red", prefix='fa')).add_to(District_Map)

# %%
District_Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import pandas as pd
import json
from folium import plugins
import pickle
import googlemaps
from geopy.geocoders import Nominatim

# %%
cases.iloc[0]
# Out:
# lat    30.458944
# lng    30.919836
# Name: 0, dtype: float64

# %%
origin_latitude = cases.iloc[0][0]

# %%
origin_longitude =  cases.iloc[0][1]

# %%
# I will calculate the distance between my point and each hospital through google maps
# Also which one will be the fastest to reach

# %%
hospitals[:2]
# Out:
#          lat        lng
# 0  30.035425  30.799747
# 1  30.187485  30.929959

# %%
hospitals.iloc[-1]

# %%
euclidean_diff  = []
for j in range (len(hospitals)):
    euclidean_lst = []
    
    euclidean_lst.append(hospitals.iloc[j][0])
    euclidean_lst.append(hospitals.iloc[j][1])
    
    euclidean_distance = math.sqrt( (origin_latitude-hospitals.iloc[j][0])**2 + (origin_longitude-hospitals.iloc[j][1])**2 )
    euclidean_lst.append(euclidean_distance)

    
        
    euclidean_diff.append(euclidean_lst)

# %%
euclidean = pd.DataFrame(euclidean_diff,columns = ['lat','lng','diff'])

# %%
euclidean['diff']
# Out:
# 0     0.440216
# 1     0.271648
# 2     0.325997
# 3     0.385485
# 4     0.551928
# 5     0.628575
# 6     0.753017
# 7     0.227641
# 8     0.607390
# 9     0.686981
# 10    1.020551
# 11    0.718031
# 12    0.796512
# 13    0.192604
# 14    0.233144
# 15    0.101543
# 16    0.324777
# 17    0.375374
# 18    0.504668
# 19    0.421398
# Name: diff, dtype: float64

# %%
euclidean[euclidean['diff'] == min(euclidean['diff'])]
# Out:
#          lat       lng      diff
# 15  30.37046  30.87002  0.101543

# %%
# https://pypi.org/project/geopy/
geolocator = Nominatim(user_agent="billy")
gmaps = googlemaps.Client(key='AIzaSyBvlpHn6Gtr6pEauCMMI1Ct9l5RqifmXm4')

# %%
for i in range(len(hospitals)):
    destination_latitude = hospitals.iloc[i]['lat']
    destination_longitude = hospitals.iloc[i]['lng']

# %%
print (origin_latitude)
print (origin_longitude)
print (destination_latitude)
print (destination_longitude)
# Out:
# 30.458944
# 30.919836
# 30.038987
# 30.885013

# %%
## https://pypi.org/project/geopy/
#geolocator = Nominatim(user_agent="billy")
#gmaps = googlemaps.Client(key='AIzaSyBvlpHn6Gtr6pEauCMMI1Ct9l5RqifmXm4')  

# Use the below coordinates as an example
#origin_latitude = 40.78826064
#origin_longitude = -73.95100594
#destination_latitude = 40.79847693
#destination_longitude = -73.93477916

# %%
# Requires cities name 
my_dist = gmaps.distance_matrix((origin_latitude, origin_longitude), 
                          (destination_latitude, destination_longitude))['rows'][0]['elements'][0]['duration']['text']

# Printing the result 
print(my_dist)
# Out:
# 1 hour 19 mins

# %%
directions_result = gmaps.directions((origin_latitude, origin_longitude), 
                          (destination_latitude, destination_longitude), departure_time='now')

# %%
directions_result
# Out:
# [{'bounds': {'northeast': {'lat': 30.4589564, 'lng': 30.9349511},
#    'southwest': {'lat': 30.0366212, 'lng': 30.700669}},
#   'copyrights': 'Map data ©2020 ORION-ME',
#   'legs': [{'distance': {'text': '77.4 km', 'value': 77431},
#     'duration': {'text': '1 hour 19 mins', 'value': 4734},
#     'duration_in_traffic': {'text': '1 hour 20 mins', 'value': 4785},
#     'end_address': 'Wadi Al Natron - Al Deblomaseien Rd, Al Giza Desert, Giza Governorate, Egypt',
#     'end_location': {'lat': 30.0366212, 'lng': 30.89236},
#     'start_address': 'Unnamed Road, Madinet Menuf, Menuf, Menofia Governorate, Egypt',
#     'start_location': {'lat': 30.4589564, 'lng': 30.9199008},
#     'steps': [{'distance': {'text': '0.4 km', 'value': 436},
#       'duration': {'text': '1 min', 'value': 72},
#       'end_location': {'lat': 30.455778, 'lng': 30.9217853},
#       'html_instructions': 'Head <b>southeast</b> toward <b>Al Wasla Al Gadeda</b>',
#       'polyline': {'points': 'o_|xDk`v{DLCTOTIvA]JCzA[|@QFANENIHIBC@E?A?EAUEo@AQ@G@C@ADCZO|@c@XMFCDAHGFELGfBU'},
#       'start_location': {'lat': 30.4589564, 'lng': 30.9199008},
#       'travel_mode': 'DRIVING'},
#      {'distance': {'text': '0.6 km', 'value':
#  (30.19061, 30.78345),
#  (30.18919, 30.78558),
#  (30.18481, 30.79208),
#  (30.18008, 30.79907),
#  (30.17356, 30.80875),
#  (30.16835, 30.81643),
#  (30.16348, 30.82366),
#  (30.15789, 30.8319),
#  (30.15053, 30.84267),
#  (30.14574, 30.84989),
#  (30.1419, 30.85552),
#  (30.13939, 30.85924),
#  (30.13603, 30.86418),
#  (30.13323, 30.86838),
#  (30.13132, 30.87116),
#  (30.13081, 30.8718),
#  (30.12994, 30.87265),
#  (30.12924, 30.8732),
#  (30.12859, 30.87362),
#  (30.12794, 30.87396),
#  (30.12642, 30.87453),
#  (30.12499, 30.87475),
#  (30.12322, 30.87466),
#  (30.12194, 30.87457),
#  (30.1183, 30.87424),
#  (30.11804, 30.87408),
#  (30.11777, 30.874),
#  (30.11735, 30.87393),
#  (30.11669, 30.87384),
#  (30.11653, 30.87359),
#  (30.11575, 30.87354),
#  (30.11397, 30.87361),
#  (30.10882, 30.87315),
#  (30.10475, 30.87278),
#  (30.09974, 30.87224),
#  (30.09789, 30.87195),
#  (30.09554, 30.87162),
#  (30.09479, 30.87155),
#  (30.09393, 30.87159),
#  (30.09265, 30.87164),
#  (30.09195, 30.87175),
#  (30.0913, 30.87194),
#  (30.09105, 30.87203),
#  (30.09027, 30.87242),
#  (30.08946, 30.87295),
#  (30.08878, 30.87356),
#  (30.08856, 30.87379),
#  (30.08821, 30.8742),
#  (30.08744, 30.8754),
#  (30.08695, 30.87646),
#  (30.08623, 30.87938),
#  (30.0843, 30.88748),
#  (30.08206, 30.89684),
#  (30.0803, 30.90405),
#  (30.07986, 30.90616),
#  (30.07921, 30.90643),
#  (30.07791, 30.9065),
#  (30.07272, 30.90665),
#  (30.07011, 30.91801),
#  (30.06815, 30.92668),
#  (30.06756, 30.92924),
#  (30.06741, 30.92908),
#  (30.06401, 30.9239),
#  (30.0544, 30.90926),
#  (30.05308, 30.90714),
#  (30.05171, 30.90717),
#  (30.0472, 30.90729),
#  (30.04671, 30.90689),
#  (30.04656, 30.90658),
#  (30.0459, 30.90484),
#  (30.04559, 30.90389),
#  (30.0455, 30.90286),
#  (30.04557, 30.90222),
#  (30.04575, 30.90133),
#  (30.0457, 30.90112),
#  (30.04561, 30.90081),
#  (30.04538, 30.90047),
#  (30.04428, 30.89926),
#  (30.04299, 30.89781),
#  (30.04184, 30.89616),
#  (30.04141, 30.89564),
#  (30.04053, 30.89492),
#  (30.03852, 30.89335),
#  (30.03802, 30.89306),
#  (30.03772, 30.89294),
#  (30.03754, 30.89292),
#  (30.0374, 30.89272),
#  (30.03662, 30.89236)]

# %%
Car_icon=folium.Icon(color='white', icon='car', icon_color="red", prefix='fa')
folium.Marker((origin_latitude,origin_longitude), icon=Car_icon).add_to(District_Map)

folium.Marker(location=(points[-1]) , icon=folium.Icon(color='green')).add_to(District_Map)

#folium.RegularPolygonMarker(location=(points[30]),fill_color='blue', number_of_sides=3, radius=10).add_to(my_map)

folium.PolyLine(points).add_to(District_Map)

District_Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
